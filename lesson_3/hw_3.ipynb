# %% [markdown]
# На основе word2vec/fasttext реализовать метод поиска ближайших статей (на вход метода должен приходить запрос (какой-то вопрос) и количество вариантов вывода к примеру 5-ть, ваш метод должен возвращать 5-ть ближайших статей к этому запросу)

# %%
import pandas as pd
import numpy as np
import gensim.downloader as api
import string
import annoy
import re
import os
import gensim.models
from tqdm import tqdm
from tqdm import tqdm_notebook
from corus import load_lenta
from gensim.models import Word2Vec, FastText
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from pymorphy2 import MorphAnalyzer
from stop_words import get_stop_words
from tensorflow.keras.layers import Dense, Embedding, Flatten

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
path = '/media/dmitriy/Disk/Downloads/ai_nlp_hw_data/hw_3/lenta-ru-news.csv.gz'
records = load_lenta(path)

# %%
corpus_title = []
corpus_text = []

for num, iter in tqdm(enumerate(records)):
    corpus_title.append(iter.title)
    corpus_text.append(iter.text)
    if num == 99999:
        break
# Out:
# 0it [00:00, ?it/s]
# 99999it [00:04, 24214.57it/s]

# %%
df = pd.DataFrame(corpus_title, columns=['title'])
df['text'] = corpus_text

# %%
morpher = MorphAnalyzer()
sw = set(get_stop_words("ru"))
exclude = set(string.punctuation)

# %%
def preprocess_txt(line):
    spls = "".join(i for i in line.strip() if i not in exclude).split()
    spls = [morpher.parse(i.lower())[0].normal_form for i in spls]
    spls = [i for i in spls if i not in sw and i != ""]
    return spls

# %%
pattern = r'[^а-яА-Я0-9]'
df['text'] = df['text'].apply(lambda x: re.sub(pattern, ' ', x))

# %%
sentences = []
counter = 0

for line in tqdm_notebook(df.text):
    spls = preprocess_txt(line)
    sentences.append(spls)
    counter += 1
    if counter > 100000:
        break
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
modelW2V = Word2Vec(sentences=sentences, vector_size=100, window=5, min_count=2)

# %%
modelFT = FastText(sentences=sentences, vector_size=100, min_count=2, window=5, workers=8)

# %%
w2v_index = annoy.AnnoyIndex(100 ,'angular')
ft_index = annoy.AnnoyIndex(100 ,'angular')
index_map = {}
counter = 0
for line in tqdm_notebook(df.text):
        n_w2v = 0
        n_ft = 0
        spls = line
        index_map[counter] = spls
        question = preprocess_txt(spls)
        vector_w2v = np.zeros(100)
        vector_ft = np.zeros(100)
        for word in question:
            if word in modelW2V.wv:
                vector_w2v += modelW2V.wv[word]
                n_w2v += 1
            if word in modelFT.wv:
                vector_ft += modelFT.wv[word]
                n_ft += 1
        if n_w2v > 0:
            vector_w2v = vector_w2v / n_w2v
        if n_ft > 0:
            vector_ft = vector_ft / n_ft
        w2v_index.add_item(counter, vector_w2v)
        ft_index.add_item(counter, vector_ft)
        counter += 1
        # ограничение в  100000 строк
        if counter > 100000:
            break
w2v_index.build(10)
ft_index.build(10)
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]
# True

# %%
def get_response(question, index, model, index_map):
    question = preprocess_txt(question)
    vector = np.zeros(100)
    norm = 0
    for word in question:
        if word in model.wv:
            vector += model.wv[word]
            norm += 1
    if norm > 0:
        vector = vector / norm
    answers = index.get_nns_by_vector(vector, 5, )
    return [index_map[i] for i in answers]

# %%
TEXT = 'экономика россии'

# %%
get_response(TEXT, w2v_index, modelW2V, index_map)
# Out:
# ['Официальный представитель Международного валютного фонда  МВФ  Джерри Прайс похвалил российские власти за быстрый выход из кризиса  сообщает ТАСС  По его словам  этому поспособствовала хорошая макроэкономическая политика  Однако российской экономике не хватает структурных реформ  особенно в части улучшения инвестиционного климата  отмечает Райс   Благодаря хорошей макроэкономической политике  повышенному  экономическому  настрою  частично из за более высоких цен на нефть  темпы роста ВВП снова будут положительными     заявил представитель МВФ  Райс советует российским властям наращивать инвестиции в инфраструктуру  социально экономическую сферу  увеличивать эффективность товарного рынка  а также развивать внешнеэкономическое взаимодействие с другими странами  Джерри Райс не первый представитель МВФ  который отмечает успех российских властей в борьбе с кризисом  На Гайдаровском форуме 17 января экономику России также похвалил глава представительства МВФ в России Габриэль Ди Белла  По его словам  российская экономика может расти значительно быстрее  чем на 1 5 процента ВВП в год ',
#  'Общей проблемой для глобальной экономики является риск долгосрочной стагнации  Об этом в четверг  12 января  заявил председатель правительства России Дмитрий Медведев  сообщает ТАСС  Действия правительства России в экономике тесно связаны с мировой повесткой  несмотря на специфику ситуации  сложившейся в стране  отметил он выступая в рамках Гайдаровского форума 2017   Уже понятно  что восстановить нормальные темпы роста только за счет денежной и бюджетной политики не получится  требуются серьезные структурные реформы     сказал Медведев  Россия успешно справилась с экономическим спадом  но трудности остаются  подчеркнул премьер министр  Нормальным состоянием для любой экономики является рост на уровне потенциальных возможностей  отметил он  При этом Медведев подчеркнул  что риск технологического отставания для России велик  а дефицит инвестиций и паралич кредитной системы препятствуют экономическому росту  План действий по ускорению экономического роста до темпов выше среднемировых готовится  но все структурные решения в экономике будут приниматься максимально аккуратно  указал он  В декабре 2016 года президент России Владимир Путин поручил правительству утвердить план действий  которые позволили бы обеспечить темпы роста российской экономики на уровне выше мировых к 2019 2020 годам ',
#  'Россия сократит зависимость своей экономики от доллара в ответ на новые санкции США  Об этом в понедельник  7 августа  в интервью изданию  Международная жизнь  заявил замглавы МИД России Сергей Рябков  передает                        Экономика будет напоминать о себе и в хорошем  и в плохом смысле  Мы  конечно  активизируем работу  связанную с импортозамещением  сокращением какой то зависимости от американских платежных систем  от доллара как расчетной валюты и так далее     сказал дипломат  Он добавил  что это  становится насущной необходимостью   По мнению главы совета Центра стратегических разработок  бывшего министра финансов Алексея Кудрина  Россия может остаться под санкциями на долгие годы  что ограничит экономический рост и инвестиции  а также увеличит разрыв между страной и миром  В марте председатель ЦБ Эльвира Набиуллина заявила  что в России созданы все условия для работы платежных систем и банков в случае отключения страны от       или других ограничений  В декабре 2016 года турецкий премьер Бинали Йылдырым заявлял  что Центробанки Турции и России приступили к решению технических вопросов для перехода на национальные валюты во взаимной торговле  По его словам  на эту перспективу позитивно смотрят и в Анкаре  и в Москве  О планах России использовать национальные валюты в торговых отношениях с Вьетнамом осенью прошлого года сообщал первый вице премьер Игорь Шувалов ',
#  'Экономика России вышла из кризиса и набирает обороты  а граждане и бизнес постепенно ощутят изменения  Об этом в понедельник  11 сентября  на совещании с членами правительства заявил президент Владимир Путин  передает ТАСС   Все  что вы сказали  безусловно  говорит о том  что российская экономика из кризиса вышла  набирает обороты  и нам в этих условиях нужно сделать все для того  чтобы эту динамику сохранить     сказал глава государства  заслушав доклад главы Минэкономразвития Максима Орешкина   И участники экономической деятельности  и граждане постепенно будут ощущать позитивные факторы  происходящие в экономике     добавил президент  В конце августа председатель правительства Дмитрий Медведев заявил  что экономика России адаптировалась к внешнему давлению и перешла к росту  В апреле на встрече с Владимиром Путиным он также говорил  что экономика страны вошла в стадию роста  По прогнозу Минэкономразвития  ВВП РФ в 2017 году вырастет более чем на два процента  МВФ ждет  что экономика страны увеличится на 1 4 процента  а в                 говорят о росте в 1 8 процента ',
#  'Премьер министр России Дмитрий Медведев назвал последствия мирового финансового кризиса 2008 го года для современной экономики  Об этом он рассказал на Деловом саммите Азиатско Тихоокеанского экономического сотрудничества  АТЭС  в субботу  17 ноября  передает  Интерфакс   По его словам  глобальная экономика достаточно восстановилась за прошедшее десятилетие  многие системные ошибки  которые к нему привели  исправлены   Изменения коснулись и финансовых рынков  и управления государственным долгом  Мы все этим занимались  и в России тоже  Крупные банки пересмотрели политику в отношении активов с высокой степенью риска     заметил он  С другой стороны  восстановление идет недостаточно активно   Оживление экономики все таки идет медленно и нестабильно  К сожалению  по ряду позиций мы сегодня смотримся хуже  чем 10 лет назад     признал премьер министр  Он отметил  что совокупный мировой долг увеличился в разы  а развивающиеся рынки стали более уязвимыми  Также он обратил внимание на то  что кредитно денежная политика стала более жесткой и большинство стран не вышли на запланированные темпы роста ВВП  В октябре Медведев указал на то  что мировая экономика во многом стала хуже  чем в кризисный 2008 год  Он подчеркнул  что  в чем то мы выглядим хуже  чем было 10 лет назад   Худшим явлением современной экономики премьер министр назвал торговые войны  В ноябре он призвал страны к совместному противостоянию торговому протекционизму  который он назвал основным принципом современной экономики ']

# %%
get_response(TEXT, ft_index, modelFT, index_map)
# Out:
# ['США стремятся к обострению внешнеполитической обстановки для того  чтобы ослабить Россию  Однако Европе это невыгодно  считает бывший канцлер ФРГ Герхард Шредер  в настоящее время занимающий пост главы совета директоров  Роснефти   Об этом он заявил в четверг  19 октября  на Евразийском форуме  передает  Интерфакс    Европе и  в первую очередь  Германии нужен противоположный результат   процветающая Россия     отметил Шредер  Поэтому  по его словам  прекращение антироссийских санкций будет соответствовать интересам ЕС  Шредер также назвал бессмысленными с политической точки зрения и опасными с экономической попытки США изолировать Россию   Когда в политических отношениях происходит разрыв  невозможно предугадать последствия  В подобных ситуациях мир экономики должен обеспечивать сохранение диалога между сторонами  и мир политики должен к этому прислушиваться     подчеркнул он  Давление США с целью ослабить сотрудничество с европейцами ощущается  по словам Шредера  и в энергетической сфере  передает РИА Новости  Председатель совета директоров  Роснефти  добавил  что согласился занять этот пост для того  чтобы  показать готовность к диалогу  с Россией  Шредер возглавил совет директоров российской компании  Роснефть  в конце сентября 2017 года  В прошлом году он стал главой управляющего совета             2   оператора строительства газопровода  Северный поток 2   Бывший канцлер Германии считается выразителем интересов немецкого бизнеса  связанного с Восточным комитетом немецкой экономики и ориентированного на энергодиалог с Россией ',
#  'Россия и страны НАТО сохранили уровень сотрудничества в сферах развития Арктики и освоения космоса  несмотря на взаимные санкции  Такую точку зрения высказал в четверг  30 марта  вице премьер Дмитрий Рогозин  передает ТАСС  По его словам  Москва  как и раньше  взаимодействует с арктическими государствами    и с США  и с Канадой  и с другими странами  которые имеют отношение к НАТО    Тем не менее мы не испытываем здесь никаких проблем  которые испытывали на других международных площадках     подчеркнул вице премьер  Он добавил  что  второе такое пространство   это космос   В этой сфере  объяснил Рогозин   частично все нормально  частично все не очень хорошо   так как санкции со стороны США коснулись поставок некоторых космических агрегатов  Накануне президент Владимир Путин провел на архипелаге Земля Франца Иосифа совещание по вопросу развития артической зоны  Он  в частности  заявил  что Россия готова к освоению Арктики совместно с иностранными партнерами  Речь может идти о проектах в самых различных сферах   от освоения природных ресурсов и развития глобальных транспортных коридоров до науки и экологии  отмечал глава государства ',
#  'Пресс секретарь президента России Владимира Путина Дмитрий Песков в интервью телеканалу  Россия 24  заявил  что России удалось завершить процесс адаптации к жизни в условиях санкций и выйти на траекторию роста  Видео доступно на         канале  России 24   с 19 15    Живем в атмосфере рестрикций  санкций  Но при этом извлекаем пользу из этого  при этом адаптируем нашу экономику и завершили процесс адаптации к этим условиям  таким образом  что удалось выйти из отрицательной динамики роста  по русски говоря из траектории падения  и перейти в траекторию роста в подавляющем большинстве отраслей нашей экономики     заявил Песков  Также пресс секретарь президента отметил  что многие отрасли российской экономики демонстрируют убедительный рост  например  сельское хозяйство   Если вы возьмете наших фермеров  наших селян  то они были бы очень недовольны  если бы эти санкции сняли     добавил он  В 2014 году ЕС  США а также ряд других стран ввели ограничительные меры против России  увязав их с присоединением Крыма  а затем   с конфликтом на юго востоке Украины  В ответ Москва ввела запрет на экспорт продовольствия из большинства стран  поддержавших антироссийские санкции  Больше важных новостей в          канале  Лента дня   Подписывайся ',
#  'Глава МИД России Сергей Лавров во время пресс конференции объяснил  что мешает налаживанию отношений между Западом и Москвой  передает РИА Новости    В западном стане небольшое  но агрессивное меньшинство  которое пытается не позволить нормализовать отношения с Российской Федерацией     заявил он  Министр также сообщил журналистам  что Россия занимается своей экономикой и развивает свои возможности  быть независимыми от подобного рода эксцессов   В конце января на Всемирном экономическом форуме в Давосе бывший министр обороны США Эштон Картер предложил Пентагону разработать детальный план войны между НАТО и Россией  По словам Картера  последние 25 лет Запад не считал Россию военным противником  однако сейчас ситуация коренным образом изменилась  и теперь  война между Россией и НАТО вполне вероятна  ',
#  'Президент России Владимир Путин и президент Белоруссии Александр Лукашенко поспорили о ценах на газ для Минска в контексте создания единого энергетического пространства Евразийского экономического союза  ЕАЭС   Слова двух лидеров приводит ТАСС   Обращаю внимание на то  что сегодня у Белоруссии цена   129 долларов за тысячу кубов  в следующем году будет 127 долларов  а в ФРГ   250 долларов  Это  безусловно  большое преимущество для наших союзников по ЕАЭС  хотя  конечно  мы должны стремиться к полной унификации     заявил Путин  В ответ Лукашенко заявил  что главный партнер Минска  к сожалению или счастью не ФРГ  а Российская Федерация   Россиян же Лукашенко назвал одновременно главными партнерами и главными конкурентами  В качестве примера глава белорусского государства привел производство тракторов  которые на 60 70 процентов состоят из российских деталей   Поэтому нам надо  чтобы у нас были равные условия  прежде всего у России и Белоруссии     настаивает Лукашенко  Белорусский лидер призвал партнеров по ЕАЭС ускорить движение в сторону единого энергетического рынка   Если мы будем идти к этому  то и вопросов не будет  мы понимаем  что за год это не решить     заявил Лукашенко  Путин заверил своего коллегу  что для этого и ведется работа по созданию необходимых документов  Российский лидер также добавил  что если бы у Белоруссии не было текущего статуса  то и цена на газ для нее была бы значительно выше   Если бы Белоруссия не имела этих преимуществ  связанных с интеграцией  а цена формировалась на рыночных принципах  это было бы не 129 долларов  а под 200   вот в чем разница     подчеркнул Путин  В ответ Лукашенко начал утверждать  что эти расчеты не верны   Мы имеем худшие условия  чем Германия  я об этом не единожды говорил  Мы воевали против Германии вместе  а наши люди  еще не умершие после войны  имеют такую ситуацию     заявил Лукашенко  намекнув на разницу логистических расходов при поставках газа в Белоруссию и Германию  Путин отказался продолжать полемику и предложил белорусскому президенту продолжить переговоры в закрытом для прессы режиме  Белорусский президент уже не первый раз высказывает сомнения относительно единого экономического пространства внутри ЕАЭС  В конце ноября Лукашенко выразил недовольство таможенными квотами и пошлинами внутри союза ']
